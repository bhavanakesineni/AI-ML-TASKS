# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanakesineni/AI-ML-TASKS/blob/main/TASK1B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
# Loading the dataset
df = pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             291
# 1           Clean Alternative Fuel Vehicle Eligible             150
# ...

# %%
df.tail()
# Out:
#        VIN (1-10) County         City State  Postal Code  Model Year  \
# 34877  7SAYGDEE6N   King    Sammamish    WA      98074.0        2022
# 34878  1G1FY6S00P   King       Seatac    WA      98148.0        2023
# 34879  5YJSA1E16H   King       Medina    WA      98039.0        2017
# 34880  KNDCR3L19P   King       Renton    WA      98057.0        2023
# 34881  7SAYGDEE8P   King  Federal Way    WA      98003.0        2023
#
#             Make     Model           Electric Vehicle Type  \
# 34877      TESLA   MODEL Y  Battery Electric Vehicle (BEV)
# 34878  CHEVROLET  BOLT EUV  Battery Electric Vehicle (BEV)
# 34879      TESLA   MODEL S  Battery Electric Vehicle (BEV)
# 34880        KIA      NIRO  Battery Electric Vehicle (BEV)
# 34881      TESLA   MODEL Y  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 34877  Eligibility unknown as battery range has not b...               0
# ...

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  34881.000000  34882.000000    34882.000000   34882.000000
# mean   98173.962788   2020.394587       62.977983    1155.082134
# std      209.448553      2.937412       94.377272    8536.359927
# min    98001.000000   1998.000000        0.000000       0.000000
# 25%    98034.000000   2018.000000        0.000000       0.000000
# 50%    98109.000000   2021.000000        6.000000       0.000000
# 75%    98188.000000   2023.000000       84.000000       0.000000
# max    99362.000000   2024.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          34881.000000    3.488200e+04       3.488000e+04
# mean              32.268198    2.163777e+08       5.303347e+10
# std               14.519451    7.876723e+07       1.161823e+07
# min                1.000000    1.100570e+05       5.300796e+10
# 25%               20.000000    1.789501e+08       5.303301e+10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34882 entries, 0 to 34881
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         34882 non-null  object
#  1   County                                             34881 non-null  object
#  2   City                                               34881 non-null  object
#  3   State                                              34882 non-null  object
#  4   Postal Code                                        34881 non-null  float64
#  5   Model Year                                         34882 non-null  int64
#  6   Make                                               34882 non-null  object
#  7   Model                                              34882 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 1
# DOL Vehicle ID                                       0
# Vehicle Location                                     1
# Electric Utility                                     2
# 2020 Census Tract                                    2
# dtype: int64

# %%
df["Electric Utility"].value_counts().idxmax()
# Out:
# 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'

# %%
df["Electric Utility"].fillna("PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)",inplace=True)

# %%
print(df['County'].dtype)
# Out:
# object

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd
county_counts = df['County'].value_counts()
plt.bar(county_counts.index, county_counts)
plt.xlabel('Country Names')
plt.ylabel('Frequency')
plt.title('Histogram of Country Names')
plt.show()

# %%
plt.boxplot(df['Model Year'])
plt.xlabel('Year')
plt.ylabel('values')
plt.title('Boxplot of Numerical Column')
plt.show()

# %%
# Assuming df is your DataFrame
correlation_matrix = df.corr()
# Use a heatmap to visualize the correlation matrix
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='plasma')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-18-59afec99f1df>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
