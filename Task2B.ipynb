# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanakesineni/AI-ML-TASKS/blob/main/Task2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                  #numpy library(for data-preprocessing)
import pandas as pd                 #pandas library(for data-preprocessing)
import matplotlib.pyplot as plt     #for data visualization
import seaborn as sns               #for data visualization

# %% [markdown]
# Loading Dataset using pandas

# %%
import pandas as pd
df = pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %% [markdown]
# head() function will display the starting rows of the dataset. By default it will display first five.

# %%
df.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           291.0
# 1           Clean Alternative Fuel Vehicle Eligible           150.0
# 2           Clean Alternative Fuel Vehicle Eligible           200.0
# 3           Clean Alternative Fuel Vehicle Eligible            47.0
# 4             Not eligible due to low battery range            23.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  22.0     124535071.0
# 1        0.0                  45.0     102359449.0
# 2        0.0                  33.0     228682037.0
# 3        0.0                  23.0     171566447.0
# 4        0.0                  22.0     234923230.0
#
#                   Vehicle Location  \
# 0  POINT (-122.7474291 47.0821119)
# 1  POINT (-122.0313266 47.6285782)
# 2  POINT (-122.2012521 47.3931814)
# 3     POINT (-122.64177 47.737525)
# 4     POINT (-122.89692 47.043535)
#
#                                 Electric Utility  2020 Census Tract
# 0                         PUGET SOUND ENERGY INC       5.306701e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.303509e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10

# %% [markdown]
# tail() function will display the last rows of the dataset. By default it will display last five.

# %%
df.tail()
# Out:
#        VIN (1-10) County         City State  Postal Code  Model Year  \
# 26168  7SAYGDEF6P  Clark    Vancouver    WA      98665.0        2023
# 26169  5YJ3E1EC0P   King     Bellevue    WA      98006.0        2023
# 26170  5UXKT0C34H   King     Issaquah    WA      98029.0        2017
# 26171  4JGGM1CB0P   King  Federal Way    WA      98023.0        2023
# 26172  5YJSA1E27J   King      Redmond    WA      98052.0        2018
#
#                 Make          Model                   Electric Vehicle Type  \
# 26168          TESLA        MODEL Y          Battery Electric Vehicle (BEV)
# 26169          TESLA        MODEL 3          Battery Electric Vehicle (BEV)
# 26170            BMW             X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 26171  MERCEDES-BENZ  EQE-CLASS SUV          Battery Electric Vehicle (BEV)
# 26172          TESLA        MODEL S          Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 26168  Eligibility unknown as battery range has not b...             0.0
# 26169  Eligibility unknown as battery range has not b...             0.0
# 26170              Not eligible due to low battery range            14.0
# 26171  Eligibility unknown as battery range has not b...             0.0
# 26172                                  Clean Alternative             NaN
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 26168        0.0                  49.0     221482488.0
# 26169        0.0                  41.0     230799866.0
# 26170        0.0                   5.0     227300608.0
# 26171        0.0                  30.0     257580690.0
# 26172        NaN                   NaN             NaN
#
#                       Vehicle Location  \
# 26168     POINT (-122.66592 45.678565)
# 26169     POINT (-122.16937 47.571015)
# 26170  POINT (-121.9993659 47.5484866)
# 26171      POINT (-122.36363 47.30675)
# 26172                              NaN
#
#                                         Electric Utility  2020 Census Tract
# 26168  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10
# 26169      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 26170      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 26171      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 26172                                                NaN                NaN

# %% [markdown]
# The shape of a DataFrame is a tuple of array dimensions that tells the number of rows and columns of a given DataFrame.

# %%
df.shape
# Out:
# (26173, 17)

# %% [markdown]
# info() method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26173 entries, 0 to 26172
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         26173 non-null  object
#  1   County                                             26172 non-null  object
#  2   City                                               26172 non-null  object
#  3   State                                              26173 non-null  object
#  4   Postal Code                                        26172 non-null  float64
#  5   Model Year                                         26173 non-null  int64
#  6   Make                                               26173 non-null  object
#  7   Model                                              26173 non-null  object
#  8   Electric Vehicle Type                              26173 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  26173 non-null  object
#  10  Electric Range                                     26172 non-null  float64
#  11  Base MSRP                                          26172 non-null  float64
#  12  Legislative District                               26171 non-null  float64
#  13  DOL Vehicle ID                                     26172 non-null  float64
#  14  Vehicle Location                                   26171 non-null  object
#  15  Electric Utility                                   26171 non-null  object
#  16  2020 Census Tract                                  26171 non-null  float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 3.4+ MB

# %% [markdown]
# The describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the DataFrame.

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  26172.000000  26173.000000    26172.000000   26172.000000
# mean   98173.945858   2020.382570       63.622001    1198.667278
# std      211.290571      2.939103       94.685833    8693.594900
# min    98001.000000   2000.000000        0.000000       0.000000
# 25%    98033.000000   2018.000000        0.000000       0.000000
# 50%    98108.000000   2021.000000        6.000000       0.000000
# 75%    98188.000000   2023.000000       84.000000       0.000000
# max    99362.000000   2024.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          26171.000000    2.617200e+04       2.617100e+04
# mean              32.561270    2.165716e+08       5.303340e+10
# std               14.545406    7.938145e+07       1.155842e+07
# min                1.000000    1.100570e+05       5.300796e+10
# 25%               20.000000    1.786375e+08       5.303301e+10
# 50%               37.000000    2.239280e+08       5.303302e+10
# 75%               45.000000    2.492100e+08       5.303303e+10
# max               49.000000    4.789259e+08       5.307794e+10

# %% [markdown]
# The isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False

# %%
df.isnull()
# Out:
#        VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0           False   False  False  False        False       False  False
# 1           False   False  False  False        False       False  False
# 2           False   False  False  False        False       False  False
# 3           False   False  False  False        False       False  False
# 4           False   False  False  False        False       False  False
# ...           ...     ...    ...    ...          ...         ...    ...
# 26168       False   False  False  False        False       False  False
# 26169       False   False  False  False        False       False  False
# 26170       False   False  False  False        False       False  False
# 26171       False   False  False  False        False       False  False
# 26172       False   False  False  False        False       False  False
#
#        Model  Electric Vehicle Type  \
# 0      False                  False
# 1      False                  False
# 2      False                  False
# 3      False                  False
# 4      False                  False
# ...      ...                    ...
# 26168  False                  False
# 26169  False                  False
# 26170  False                  False
# 26171  False                  False
# 26172  False                  False
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  False           False
# 1                                                  False           False
# 2                                                  False           False
# 3                                                  False           False
# 4                                                  False           False
# ...                                                  ...             ...
# 26168                                              False           False
# 26169                                              False           False
# 26170                                              False           False
# 26171                                              False           False
# 26172                                              False            True
#
#        Base MSRP  Legislative District  DOL Vehicle ID  Vehicle Location  \
# 0          False                 False           False             False
# 1          False                 False           False             False
# 2          False                 False           False             False
# 3          False                 False           False             False
# 4          False                 False           False             False
# ...          ...                   ...             ...               ...
# 26168      False                 False           False             False
# 26169      False                 False           False             False
# 26170      False                 False           False             False
# 26171      False                 False           False             False
# 26172       True                  True            True              True
#
#        Electric Utility  2020 Census Tract
# 0                 False              False
# 1                 False              False
# 2                 False              False
# 3                 False              False
# 4                 False              False
# ...                 ...                ...
# 26168             False              False
# 26169             False              False
# 26170             False              False
# 26171             False              False
# 26172              True               True
#
# [26173 rows x 17 columns]

# %% [markdown]
# The function dataframe. isnull().sum() returns the number of missing values in the dataset

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       1
# Base MSRP                                            1
# Legislative District                                 2
# DOL Vehicle ID                                       1
# Vehicle Location                                     2
# Electric Utility                                     2
# 2020 Census Tract                                    2
# dtype: int64

# %% [markdown]
# We are having some null values. we will use value_counts() - The value_counts() function returns an object containing counts of unique values. This means it enables us to count the number of unique elements in a column of a Pandas dataframe.

# %%
df['County'].value_counts()
# Out:
# King           19726
# Clark           2515
# Snohomish       1243
# Kitsap          1187
# Thurston         710
# Cowlitz          238
# Jefferson        219
# Yakima           182
# Island            84
# Stevens           23
# Clallam           22
# Klickitat          5
# Skagit             5
# Chelan             4
# Walla Walla        3
# Kittitas           2
# Spokane            2
# Whitman            1
# Grant              1
# Name: County, dtype: int64

# %% [markdown]
# Now replace the null values with some random value using fillna() -The fillna() method replaces the NULL values with a specified value.

# %%
df['County'].fillna(3102, inplace = True)

# %%
df['City'].value_counts()
# Out:
# Seattle        5192
# Bellevue       2758
# Kirkland       2182
# Vancouver      1705
# Redmond        1240
#                ...
# Darrington        1
# Leavenworth       1
# Manson            1
# Moses Lake        1
# Outlook           1
# Name: City, Length: 140, dtype: int64

# %%
df['City'].fillna(2000, inplace = True)

# %%
df['Postal Code'].value_counts()
# Out:
# 98052.0    1240
# 98188.0    1153
# 98034.0    1141
# 98033.0    1041
# 98004.0     831
#            ...
# 98274.0       1
# 98922.0       1
# 98801.0       1
# 99163.0       1
# 98051.0       1
# Name: Postal Code, Length: 206, dtype: int64

# %%
df['Postal Code'].fillna(520001, inplace = True)

# %%
df['Legislative District'].value_counts()
# Out:
# 45.0    2728
# 48.0    2580
# 41.0    2483
# 11.0    1944
# 46.0    1568
# 43.0    1269
# 1.0     1180
# 36.0    1177
# 18.0    1127
# 32.0    1067
# 17.0     951
# 47.0     917
# 33.0     878
# 23.0     850
# 37.0     721
# 34.0     633
# 5.0      603
# 22.0     412
# 49.0     399
# 44.0     352
# 21.0     300
# 30.0     296
# 24.0     241
# 26.0     224
# 35.0     219
# 20.0     196
# 39.0     149
# 2.0      133
# 19.0     128
# 10.0     106
# 14.0     105
# 15.0      93
# 31.0      80
# 38.0      24
# 7.0       23
# 12.0       4
# 16.0       3
# 13.0       3
# 3.0        2
# 40.0       2
# 9.0        1
# Name: Legislative District, dtype: int64

# %%
df['Legislative District'].fillna(1000, inplace = True)

# %%
df['Vehicle Location'].value_counts()
# Out:
# POINT (-122.12302 47.67668)      1239
# POINT (-122.29179 47.43473)      1153
# POINT (-122.209285 47.71124)     1141
# POINT (-122.20264 47.6785)       1041
# POINT (-122.201905 47.61385)      831
#                                  ...
# POINT (-122.322955 48.4152)         1
# POINT (-120.938305 47.195355)       1
# POINT (-120.32009 47.42255)         1
# POINT (-117.17912 46.730885)        1
# POINT (-121.98104 47.358625)        1
# Name: Vehicle Location, Length: 206, dtype: int64

# %%
df['Vehicle Location'].fillna(3000, inplace = True)

# %%
df['Electric Utility'].value_counts()
# Out:
# PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                                               13433
# CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                                                 6273
# PUGET SOUND ENERGY INC                                                                       3163
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)                             2473
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY                                   238
# BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY         208
# PACIFICORP                                                                                    165
# BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHOMISH COUNTY                                     56
# BONNEVILLE POWER ADMINISTRATION||PACIFICORP||PUD NO 1 OF CLARK COUNTY - (WA)                   42
# NO KNOWN ELECTRIC UTILITY SERVICE                                                              33
# BONNEVILLE POWER ADMINISTRATION||PACIFICORP||BENTON RURAL ELECTRIC ASSN                        19
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY                                    13
# CITY OF TACOMA - (WA)||TANNER ELECTRIC COOP                                                    13
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF MASON COUNTY|PUD NO 1 OF JEFFERSON COUNTY         10
# BONNEVILLE POWER ADMINISTRATION||CITY OF PORT ANGELES - (WA)                                    8
# AVISTA CORP                                                                                     5
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KLICKITAT COUNTY                                   5
# PUD NO 1 OF CHELAN COUNTY                                                                       4
# MODERN ELECTRIC WATER COMPANY                                                                   2
# CITY OF TACOMA - (WA)                                                                           2
# BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY                 2
# PUD NO 2 OF GRANT COUNTY                                                                        1
# BONNEVILLE POWER ADMINISTRATION||BENTON RURAL ELECTRIC ASSN                                     1
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY|PUD NO 1 OF JEFFERSON COUNTY        1
# BONNEVILLE POWER ADMINISTRATION||CITY OF MILTON - (WA)|CITY OF TACOMA - (WA)                    1
# Name: Electric Utility, dtype: int64

# %%
df['Electric Utility'].fillna(3549, inplace = True)

# %%
df['2020 Census Tract'].value_counts()
# Out:
# 5.303303e+10    1114
# 5.303303e+10     431
# 5.303303e+10     323
# 5.303303e+10     278
# 5.303302e+10     219
#                 ...
# 5.307794e+10       1
# 5.303995e+10       1
# 5.303301e+10       1
# 5.301500e+10       1
# 5.303300e+10       1
# Name: 2020 Census Tract, Length: 913, dtype: int64

# %%
df['2020 Census Tract'].fillna(449, inplace = True)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       1
# Base MSRP                                            1
# Legislative District                                 0
# DOL Vehicle ID                                       1
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %% [markdown]
# Univariate analysis refers to the statistical analysis of a single variable at a time. It is the simplest form of statistical analysis because it deals with only one variable. The main purpose of univariate analysis is to describe the distribution of data and to understand the central tendency and dispersion of a variable.

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# Let us Consider City column to analyze the univariate analysis

# %%
categorical_data = df['Make']

# %%
value_counts = categorical_data.value_counts()

# %%
value_counts
# Out:
# TESLA                   12221
# NISSAN                   2208
# CHEVROLET                1856
# BMW                      1151
# FORD                     1063
# KIA                      1050
# TOYOTA                    862
# JEEP                      806
# VOLKSWAGEN                653
# HYUNDAI                   637
# VOLVO                     590
# AUDI                      534
# CHRYSLER                  485
# RIVIAN                    436
# SUBARU                    236
# MERCEDES-BENZ             224
# PORSCHE                   176
# POLESTAR                  156
# MITSUBISHI                145
# MINI                      136
# FIAT                      127
# HONDA                     107
# MAZDA                      45
# LEXUS                      45
# SMART                      44
# LUCID                      37
# CADILLAC                   36
# LINCOLN                    31
# JAGUAR                     31
# GENESIS                    29
# LAND ROVER                  7
# ALFA ROMEO                  3
# DODGE                       2
# FISKER                      1
# AZURE DYNAMICS              1
# TH!NK                       1
# WHEEGO ELECTRIC CARS        1
# Name: Make, dtype: int64

# %%
plt.figure(figsize=(25, 10))
sns.countplot(x=categorical_data, palette='viridis')
plt.title('Distribution of Categorical Variable')
plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.show()

# %%
percentage_distribution = value_counts / len(categorical_data) * 100
print("Percentage Distribution:")
print(percentage_distribution)
# Out:
# Percentage Distribution:
# TESLA                   46.693157
# NISSAN                   8.436175
# CHEVROLET                7.091277
# BMW                      4.397662
# FORD                     4.061437
# KIA                      4.011768
# TOYOTA                   3.293470
# JEEP                     3.079509
# VOLKSWAGEN               2.494938
# HYUNDAI                  2.433806
# VOLVO                    2.254231
# AUDI                     2.040271
# CHRYSLER                 1.853055
# RIVIAN                   1.665839
# SUBARU                   0.901693
# MERCEDES-BENZ            0.855844
# PORSCHE                  0.672449
# POLESTAR                 0.596034
# MITSUBISHI               0.554006
# MINI                     0.519619
# FIAT                     0.485233
# HONDA                    0.408818
# MAZDA                    0.171933
# LEXUS                    0.171933
# SMART                    0.168112
# LUCID                    0.141367
# CADILLAC                 0.137546
# LINCOLN                  0.118443
# JAGUAR                   0.118443
# GENESIS                  0.110801
# LAND ROVER               0.026745
# ALFA ROMEO               0.011462
# DODGE                    0.007641
# FISKER                   0.003821
# AZURE DYNAMICS           0.003821
# TH!NK                    0.003821
# WHEEGO ELECTRIC CARS     0.003821
# Name: Make, dtype: float64

# %%
plt.figure(figsize=(10,10))
plt.pie(percentage_distribution, labels=percentage_distribution.index, autopct='%1.1f%%', colors=sns.color_palette('viridis'))
plt.title('Percentage Distribution of Categorical Variable')
plt.show()
